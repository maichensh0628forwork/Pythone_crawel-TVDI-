# %%
print(3+5)
print(90-80)
print(7/2)
print(7//2)
print(7%3)
print(7*3)
print(3**4)
print(99**99)



2 * (1 + 2) ** 2 - 2 ** 2 * 2
# Out:
# 8
# 10
# 3.5
# 3
# 1
# 21
# 81
# 369729637649726772657187905628805440595668764281741102430259972423552570455277523421410650010128232727940978889548326540119429996769494359451621570193644014418071060667659301384999779999159200499899

# %%
# python的基本資料型別
# int (整數)
5
15

# float (浮點數)
5.0

# str (字串)
"5"
'5'

#  bool (布林值)
True
False

5 + 5

5 + 5.0

5 + int('5')
# Out:
# 10

# %%
78 + 95 + 83 + 69 + 70
2+3*4
(2+3)*4
2 * (1 + 2) ** 2 - 2 ** 2 * 2
# Out:
# 10

# %%
2 * (1 + 2) ** 2 - 2 ** 2 * 2 #運算式
VALUE = 2 * (1 + 2) ** 2 - 2 ** 2 * 2 #敘述式
VALUE
# Out:
# 10

# %%
#求三科平均 

chinese = 78
english = 92
math = 67
chinese = chinese +5

total = chinese + english + math

average = total / 3
average
# Out:
# 80.66666666666667

# %%
# 複合指定運算子


chinese = 78
chinese += 5
chinese *= 10


# chinese 開平方根
import math #先加入函數庫

value = math.sqrt(chinese)
value = round(value,ndigits=2)
value
# Out:
# 28.81

# %%
# 複合指定運算子
import math

chinese = 78
chinese += 5
chinese *= 10

# chinese 開平方根
value = round(math.sqrt(chinese),ndigits=2) # 可一行做多件事

value
# Out:
# 28.81

# %%
練習題：計算體重指數 BMI
BMI（Body Mass Index，身體質量指數）是評估體重是否健康的常用指標。

計算公式：
BMI = 體重(公斤) ÷ 身高(公尺)²

題目要求：

建立變數 weight 儲存體重 72 公斤
建立變數 height 儲存身高 175 公分（注意：公式需要公尺，請先除以 100）
使用 ** 運算子計算身高的平方
計算 BMI 值並儲存在變數 bmi 中
使用 round() 函式將 BMI 四捨五入到小數點後 2 位
印出結果
參考輸出：
23.35

提示：

身高需轉換成公尺：height = 175 / 100
平方使用 ** 運算子：height ** 2
四捨五入：round(bmi, 2)
# Out:
#   Cell In[23], line 1
#     練習題：計算體重指數 BMI
#        ^
# SyntaxError: invalid character '：' (U+FF1A)

# %%
# BMI 計算

weight = 72
height = 175/100
BMI = weight /( height**2)
BMI = round(BMI,2)
BMI
# Out:
# 23.51

# %%
# BMI 計算

weight = 72 
height = 175/100

BMI= weight / height**2 
BMI = round(BMI,2)
BMI
# Out:
# 23.51
